# %%
import pandas as pd

# %%
#convert csv to dataframe
df = pd.read_csv('/Users/arijuljulian/Development/players.csv')

# %%
df
# Out:
#       id                              name  now_cost position     team  \
# 0      1                   Folarin Balogun        45      FWD  Arsenal
# 1      2               Cédric Alves Soares        40      DEF  Arsenal
# 2      3                    Mohamed Elneny        45      MID  Arsenal
# 3      4             Fábio Ferreira Vieira        55      MID  Arsenal
# 4      5      Gabriel dos Santos Magalhães        50      DEF  Arsenal
# ..   ...                               ...       ...      ...      ...
# 639  572              Nélson Cabral Semedo        45      DEF   Wolves
# 640  573                Toti António Gomes        45      DEF   Wolves
# 641  574                   Boubacar Traoré        45      MID   Wolves
# 642  590  Matheus Santos Carneiro Da Cunha        55      FWD   Wolves
# 643  598                      Matt Doherty        45      DEF   Wolves
#
#      ict_index_rank_type  creativity_rank  penalties_order  clean_sheets  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644 entries, 0 to 643
# Data columns (total 66 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    644 non-null    int64
#  1   name                                  644 non-null    object
#  2   now_cost                              644 non-null    int64
#  3   position                              644 non-null    object
#  4   team                                  644 non-null    object
#  5   ict_index_rank_type                   644 non-null    int64
#  6   creativity_rank                       644 non-null    int64
#  7   penalties_order                       45 non-null     float64
#  8   clean_sheets                          644 non-null    int64
#  9   transfers_out                         644 non-null    int64
#  10  minutes                               644 non-null    int64
# ...
